# %% [markdown]
# **Ejemplo 2**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#En caso de no poder cargar el archivo con seaborns leerlo con pandas
df= pd.read_csv("Leads_Reales_sin_valores_atipicos.csv")

# %%
df['Mes']=df['Mes'].str.replace('Enero','1').str.replace('Febrero','2').str.replace('Marzo','3').str.replace('Abril','4').str.replace('Mayo','5').str.replace('Junio','6').str.replace('Julio','7').str.replace('Agosto','8').str.replace('Septiembre','9').str.replace('Octubre','10').str.replace('Noviembre','11').str.replace('Diciembre','12')
df
# Out:
#     Mes   Año  Total  Ilocalizable  No Contesta  D. Incorrectos  Duplicados  \
# 0     1  2024      0             0            0               0           0
# 1     2  2024    543           108           33               0           1
# 2     3  2024    178            37           13               0           0
# 3     4  2024    416            79           46               3           0
# 4     5  2024    422            33          100              17           0
# 5     6  2024    967           140          173              31           3
# 6     7  2024    954           112          251              12           9
# 7     8  2024   1409           504          324              17          18
# 8     9  2024   1315           431          314              14          26
# 9    10  2024   1973           514          606              18          13
# 10   11  2024   1562           153          321              44           4
# ...

# %%
#Graficamos todas las dispersiones entre todas las variables
sns.pairplot(df)

# %%
#Encontramos todas las correlaciones entre las variables 
Corr_Factors=df.corr()
Corr_Factors
# Out:
#                            Mes       Año     Total  Ilocalizable  No Contesta  \
# Mes                   1.000000 -0.298181  0.479697      0.422512     0.665231
# Año                  -0.298181  1.000000  0.390258     -0.220409    -0.075146
# Total                 0.479697  0.390258  1.000000      0.599487     0.669922
# Ilocalizable          0.422512 -0.220409  0.599487      1.000000     0.468315
# No Contesta           0.665231 -0.075146  0.669922      0.468315     1.000000
# D. Incorrectos        0.050075  0.210277  0.480309      0.317660     0.007697
# Duplicados            0.111702  0.453710  0.414828     -0.026033     0.170971
# Efectivos             0.431038  0.427469  0.853120      0.302049     0.446789
# Abiertos              0.103614  0.808063  0.551099     -0.009711     0.061847
# Ventas                0.273725  0.746773  0.621679     -0.018107     0.297785
# Conversion            0.079185  0.550205  0.137652     -0.246187     0.060263
# ...

# %%
#Encontramos el valor absoluto de todas las correlaciones entre las variables 
Corr_Factors1= abs(Corr_Factors)
Corr_Factors1
# Out:
#                            Mes       Año     Total  Ilocalizable  No Contesta  \
# Mes                   1.000000  0.298181  0.479697      0.422512     0.665231
# Año                   0.298181  1.000000  0.390258      0.220409     0.075146
# Total                 0.479697  0.390258  1.000000      0.599487     0.669922
# Ilocalizable          0.422512  0.220409  0.599487      1.000000     0.468315
# No Contesta           0.665231  0.075146  0.669922      0.468315     1.000000
# D. Incorrectos        0.050075  0.210277  0.480309      0.317660     0.007697
# Duplicados            0.111702  0.453710  0.414828      0.026033     0.170971
# Efectivos             0.431038  0.427469  0.853120      0.302049     0.446789
# Abiertos              0.103614  0.808063  0.551099      0.009711     0.061847
# Ventas                0.273725  0.746773  0.621679      0.018107     0.297785
# Conversion            0.079185  0.550205  0.137652      0.246187     0.060263
# ...

# %%
#Ajustamos el mapa de calor de los coeficientes de correlación 
Heat_Map= sns.heatmap(Corr_Factors1, cmap = 'Blues', annot=True, fmt=".2f")  
Heat_Map
# Out:
# <Axes: >

# %%
#Imprimimos el scatter plot entre la variable dependiente (total) e independiente (alcohol) 
#para observar el comportamiento en su dispersión 
from turtle import color
sns.scatterplot(x='No Contesta', y='Total', color="blue", data=df)
# Out:
# <Axes: xlabel='No Contesta', ylabel='Total'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
#Vars_Indep= df[['alcohol', 'speeding']]
Vars_Indep= df[['No Contesta']]
Var_Dep= df['Total']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'tol': 1e-06,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['No Contesta'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([1.99328067]),
#  'rank_': np.int64(1),
#  'singular_': array([824.91015185]),
#  'intercept_': np.float64(681.082831884704)}

# %% [markdown]
# **Modelo matemático: y= 1.99328067(x) + 681.082831884704**

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.4487955686064048

# %%
#Predecimos los valores de total de Leads a partir de la variable "Efectivos"
#y_pred= model.predict(X=df[['alcohol', 'speeding']])
y_pred= model.predict(X=df[['No Contesta']])
y_pred
# Out:
# array([ 681.08283188,  746.86109414,  706.99548065,  772.77374291,
#         880.41089934, 1025.92038858, 1181.39628119, 1326.90577043,
#        1306.97296368, 1889.01092064, 1320.9259284 , 1065.78600207,
#         888.38402203,  758.82077819,  876.42433799,  948.18244227,
#         830.57888247, 1211.29549131, 1161.46347444, 1859.11171052,
#        1480.38838236, 1504.30775046, 1115.61801893, 1067.77928274,
#        1053.82631802,  892.37058338, 1047.846476  ,  926.25635485,
#         912.30339013])

# %%
#Insertamos la columna de predicciones en el DataFrame
df.insert(0, 'Predicciones', y_pred)
df
# Out:
#     Predicciones  Mes   Año  Total  Ilocalizable  No Contesta  D. Incorrectos  \
# 0     681.082832    1  2024      0             0            0               0
# 1     746.861094    2  2024    543           108           33               0
# 2     706.995481    3  2024    178            37           13               0
# 3     772.773743    4  2024    416            79           46               3
# 4     880.410899    5  2024    422            33          100              17
# 5    1025.920389    6  2024    967           140          173              31
# 6    1181.396281    7  2024    954           112          251              12
# 7    1326.905770    8  2024   1409           504          324              17
# 8    1306.972964    9  2024   1315           431          314              14
# 9    1889.010921   10  2024   1973           514          606              18
# 10   1320.925928   11  2024   1562           153          321              44
# ...

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido

sns.scatterplot(x='No Contesta', y='Total', color="blue", data=df)
sns.scatterplot(x='No Contesta', y='Predicciones', color="red", data=df)
sns.lineplot(x='No Contesta', y='Predicciones', color="red", data=df)
# Out:
# <Axes: xlabel='No Contesta', ylabel='Total'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.4487955686064048

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# np.float64(0.6699220615910516)
